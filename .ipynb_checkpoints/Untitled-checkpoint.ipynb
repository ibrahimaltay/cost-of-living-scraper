# %%
from bs4 import BeautifulSoup
import requests
import time
import csv
import pandas as pd
COUNTRYLIST = ['Afghanistan', 'Aland+Islands', 'Albania', 'Alderney', 'Algeria', 'American+Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antigua+And+Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire', 'Bosnia+And+Herzegovina', 'Botswana', 'Brazil', 'British+Virgin+Islands', 'Brunei', 'Bulgaria', 'Burkina+Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape+Verde', 'Cayman+Islands', 'Central+African+Republic', 'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook+Islands', 'Costa+Rica', 'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech+Republic', 'Denmark', 'Djibouti', 'Dominica', 'Dominican+Republic', 'Ecuador', 'Egypt', 'El+Salvador', 'Equatorial+Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Falkland+Islands', 'Faroe+Islands', 'Fiji', 'Finland', 'France', 'French+Guiana', 'French+Polynesia', 'French+Southern+Territories', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'Hong+Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle+Of+Man', 'Israel', 'Italy', 'Ivory+Coast', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kosovo+%28Disputed+Territory%29', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall+Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Micronesia', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Netherlands', 'New+Caledonia', 'New+Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'North+Korea', 'North+Macedonia', 'Northern+Mariana+Islands', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Palestine', 'Panama', 'Papua+New+Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Puerto+Rico', 'Qatar', 'Republic+Of+Congo', 'Reunion', 'Romania', 'Russia', 'Rwanda', 'Saint+Helena', 'Saint+Kitts+And+Nevis', 'Saint+Lucia', 'Saint+Vincent+And+The+Grenadines', 'Samoa', 'San+Marino', 'Sao+Tome+And+Principe', 'Saudi+Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra+Leone', 'Singapore', 'Sint+Maarten', 'Slovakia', 'Slovenia', 'Solomon+Islands', 'Somalia', 'South+Africa', 'South+Korea', 'South+Sudan', 'Spain', 'Sri+Lanka', 'Sudan', 'Suriname', 'Swaziland', 'Sweden', 'Switzerland', 'Syria', 'Taiwan', 'Tajikistan', 'Tanzania', 'Thailand', 'Timor-Leste', 'Togo', 'Tonga', 'Trinidad+And+Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks+And+Caicos+Islands', 'Uganda', 'Ukraine', 'United+Arab+Emirates', 'United+Kingdom', 'United+States', 'Uruguay', 'Us+Virgin+Islands', 'Uzbekistan', 'Vanuatu', 'Vatican+City', 'Venezuela', 'Vietnam', 'Western+Sahara', 'Yemen', 'Zambia', 'Zimbabwe']
ITEMS = ['Meal, Inexpensive Restaurant ', 'Meal for 2 People, Mid-range Restaurant, Three-course ', 'McMeal at McDonalds (or Equivalent Combo Meal) ', 'Domestic Beer (0.5 liter draught) ', 'Imported Beer (0.33 liter bottle) ', 'Cappuccino (regular) ', 'Coke/Pepsi (0.33 liter bottle) ', 'Water (0.33 liter bottle)  ', 'Milk (regular), (1 liter) ', 'Loaf of Fresh White Bread (500g) ', 'Rice (white), (1kg) ', 'Eggs (regular) (12) ', 'Local Cheese (1kg) ', 'Chicken Fillets (1kg) ', 'Beef Round (1kg) (or Equivalent Back Leg Red Meat) ', 'Apples (1kg) ', 'Banana (1kg) ', 'Oranges (1kg) ', 'Tomato (1kg) ', 'Potato (1kg) ', 'Onion (1kg) ', 'Lettuce (1 head) ', 'Water (1.5 liter bottle) ', 'Bottle of Wine (Mid-Range) ', 'Domestic Beer (0.5 liter bottle) ', 'Imported Beer (0.33 liter bottle) ', 'Cigarettes 20 Pack (Marlboro) ', 'One-way Ticket (Local Transport) ', 'Monthly Pass (Regular Price) ', 'Taxi Start (Normal Tariff) ', 'Taxi 1km (Normal Tariff) ', 'Taxi 1hour Waiting (Normal Tariff) ', 'Gasoline (1 liter) ', 'Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car) ', 'Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car) ', 'Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment ', '1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans) ', 'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL) ', 'Fitness Club, Monthly Fee for 1 Adult ', 'Tennis Court Rent (1 Hour on Weekend) ', 'Cinema, International Release, 1 Seat ', 'Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child ', 'International Primary School, Yearly for 1 Child ', '1 Pair of Jeans (Levis 501 Or Similar) ', '1 Summer Dress in a Chain Store (Zara, H&M, ...) ', '1 Pair of Nike Running Shoes (Mid-Range) ', '1 Pair of Men Leather Business Shoes ', 'Apartment (1 bedroom) in City Centre ', 'Apartment (1 bedroom) Outside of Centre ', 'Apartment (3 bedrooms) in City Centre ', 'Apartment (3 bedrooms) Outside of Centre ', 'Price per Square Meter to Buy Apartment in City Centre ', 'Price per Square Meter to Buy Apartment Outside of Centre ', 'Average Monthly Net Salary (After Tax) ', 'Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate ']
CURRENCY = "USD"

# %%
def GetItems():
	URL = f"https://www.numbeo.com/cost-of-living/country_result.jsp?country=Germany&displayCurrency={CURRENCY}" 
	source = requests.get(URL).text
	soup = BeautifulSoup(source,'lxml')
	items = []
	prices = []
	table = soup.find("table", class_="data_wide_table new_bar_table")
	row = table.find_all('tr')
	for x in row:
		try:
			items.append(x.find_all('td')[0].text)
			# print(x.find_all('td')[0].text)
			# prices.append(x.find_all('td')[1].text)
			# print(x.find_all('td')[1].text)
		except Exception as e:
			pass
	return items

# %%
def GetCountryPrices(country):
    try:
        COUNTRY = country
        URL = f"https://www.numbeo.com/cost-of-living/country_result.jsp?country={COUNTRY}&displayCurrency={CURRENCY}" 
        source = requests.get(URL).text
        soup = BeautifulSoup(source,'lxml')
        print(f"SELECTED COUNTRY: {COUNTRY}\n")
        items = []
        prices = []
        table = soup.find("table", class_="data_wide_table new_bar_table")
        row = table.find_all('tr')
        for x in row:
            try:
                # items.append(x.find_all('td')[0].text)
                # print(x.find_all('td')[0].text)
                prices.append(x.find_all('td')[1].text.split('$')[0])
                # print(x.find_all('td')[1].text)
            except Exception as e:
                pass
    except Exception as e:
        print(e)
    return prices

# %%
def GetCountryList():
	source = requests.get("https://www.numbeo.com/cost-of-living/").text
	soup = BeautifulSoup(source,"lxml")
	table = soup.find("table", class_="related_links")
	anchor = table.find_all("a")
	for x in anchor:
		text = x.text
		text = text.replace(' ',"+")
		COUNTRYLIST.append(text)
	COUNTRYLIST[COUNTRYLIST.index("Kosovo+(Disputed+Territory)")]= "Kosovo+%28Disputed+Territory%29"

# %%
COUNTRYLIST
# Out:
# ['Afghanistan',
#  'Aland+Islands',
#  'Albania',
#  'Alderney',
#  'Algeria',
#  'American+Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antigua+And+Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bonaire',
#  'Bosnia+And+Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British+Virgin+Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina+Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape+Verde',
#  'Cayman+Islands',
#  'Central+African+Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Cook+Islands',
#  'Costa+Rica',
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech+Republic',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican+Republic',
#  'Ecuador',
#  'Egypt',
#  'El+Salvador',
#  'Equatorial+Guinea',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Falkland+Islands',
#  'Faroe+Islands',
#  'Fiji',
#  'Finland',
#  'France',
#  'French+Guiana',
#  'French+Polynesia',
#  'French+Southern+Territories',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guernsey',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong+Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Isle+Of+Man',
#  'Israel',
#  'Italy',
#  'Ivory+Coast',
#  'Jamaica',
#  'Japan',
#  'Jersey',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kosovo+%28Disputed+Territory%29',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Macao',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Marshall+Islands',
#  'Martinique',
#  'Mauritania',
#  'Mauritius',
#  'Mayotte',
#  'Mexico',
#  'Micronesia',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New+Caledonia',
#  'New+Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North+Korea',
#  'North+Macedonia',
#  'Northern+Mariana+Islands',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palau',
#  'Palestine',
#  'Panama',
#  'Papua+New+Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Puerto+Rico',
#  'Qatar',
#  'Republic+Of+Congo',
#  'Reunion',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saint+Helena',
#  'Saint+Kitts+And+Nevis',
#  'Saint+Lucia',
#  'Saint+Vincent+And+The+Grenadines',
#  'Samoa',
#  'San+Marino',
#  'Sao+Tome+And+Principe',
#  'Saudi+Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra+Leone',
#  'Singapore',
#  'Sint+Maarten',
#  'Slovakia',
#  'Slovenia',
#  'Solomon+Islands',
#  'Somalia',
#  'South+Africa',
#  'South+Korea',
#  'South+Sudan',
#  'Spain',
#  'Sri+Lanka',
#  'Sudan',
#  'Suriname',
#  'Swaziland',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Timor-Leste',
#  'Togo',
#  'Tonga',
#  'Trinidad+And+Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks+And+Caicos+Islands',
#  'Uganda',
#  'Ukraine',
#  'United+Arab+Emirates',
#  'United+Kingdom',
#  'United+States',
#  'Uruguay',
#  'Us+Virgin+Islands',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vatican+City',
#  'Venezuela',
#  'Vietnam',
#  'Western+Sahara',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
denemelist = ['Germany', 'United+States', 'Japan', 'China', 'France']

# %%
df = pd.DataFrame()

# %%
df.head
# Out:
# <bound method NDFrame.head of Empty DataFrame
# Columns: []
# Index: []>

# %%
df['ITEMS'] = GetItems()

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                 ITEMS
# 0                       Meal, Inexpensive Restaurant
# 1   Meal for 2 People, Mid-range Restaurant, Three...
# 2     McMeal at McDonalds (or Equivalent Combo Meal)
# 3                  Domestic Beer (0.5 liter draught)
# 4                  Imported Beer (0.33 liter bottle)
# 5                               Cappuccino (regular)
# 6                     Coke/Pepsi (0.33 liter bottle)
# 7                         Water (0.33 liter bottle)
# 8                          Milk (regular), (1 liter)
# 9                   Loaf of Fresh White Bread (500g)
# 10                               Rice (white), (1kg)
# 11                               Eggs (regular) (12)
# 12                                Local Cheese (1kg)
# 13                             Chicken Fillets (1kg)
# 14  Beef Round (1kg) (or Equivalent Back Leg Red M...
# 15                                      Apples (1kg)
# 16                                      Banana (1kg)
# 17                                     Oranges (1kg)
# 18                                      Tomato (1kg)
# 19                                      Potato (1kg)
# 20                                       Onion (1kg)
# 21                                  Lettuce (1 head)
# 22                          Water (1.5 liter bottle)
# 23                        Bottle of Wine (Mid-Range)
# 24                  Domestic Beer (0.5 liter bottle)
# 25                 Imported Beer (0.33 liter bottle)
# 26                     Cigarettes 20 Pack (Marlboro)
# 27                  One-way Ticket (Local Transport)
# 28                      Monthly Pass (Regular Price)
# 29                        Taxi Start (Normal Tariff)
# 30                          Taxi 1km (Normal Tariff)
# 31                Taxi 1hour Waiting (Normal Tariff)
# 32                                Gasoline (1 liter)
# 33  Volkswagen Golf 1.4 90 KW Trendline (Or Equiva...
# 34  Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equ...
# 35  Basic (Electricity, Heating, Cooling, Water, G...
# 36  1 min. of Prepaid Mobile Tariff Local (No Disc...
# 37  Internet (60 Mbps or More, Unlimited Data, Cab...
# 38             Fitness Club, Monthly Fee for 1 Adult
# 39             Tennis Court Rent (1 Hour on Weekend)
# 40             Cinema, International Release, 1 Seat
# 41  Preschool (or Kindergarten), Full Day, Private...
# 42  International Primary School, Yearly for 1 Child
# 43            1 Pair of Jeans (Levis 501 Or Similar)
# 44  1 Summer Dress in a Chain Store (Zara, H&M, ...)
# 45          1 Pair of Nike Running Shoes (Mid-Range)
# 46              1 Pair of Men Leather Business Shoes
# 47              Apartment (1 bedroom) in City Centre
# 48           Apartment (1 bedroom) Outside of Centre
# 49             Apartment (3 bedrooms) in City Centre
# 50          Apartment (3 bedrooms) Outside of Centre
# 51  Price per Square Meter to Buy Apartment in Cit...
# 52  Price per Square Meter to Buy Apartment Outsid...
# 53            Average Monthly Net Salary (After Tax)
# 54  Mortgage Interest Rate in Percentages (%), Yea...>

# %%
df['ITEMS']
# Out:
# 0                         Meal, Inexpensive Restaurant
# 1     Meal for 2 People, Mid-range Restaurant, Three...
# 2       McMeal at McDonalds (or Equivalent Combo Meal)
# 3                    Domestic Beer (0.5 liter draught)
# 4                    Imported Beer (0.33 liter bottle)
# 5                                 Cappuccino (regular)
# 6                       Coke/Pepsi (0.33 liter bottle)
# 7                           Water (0.33 liter bottle)
# 8                            Milk (regular), (1 liter)
# 9                     Loaf of Fresh White Bread (500g)
# 10                                 Rice (white), (1kg)
# 11                                 Eggs (regular) (12)
# 12                                  Local Cheese (1kg)
# 13                               Chicken Fillets (1kg)
# 14    Beef Round (1kg) (or Equivalent Back Leg Red M...
# 15                                        Apples (1kg)
# 16                                        Banana (1kg)
# 17                                       Oranges (1kg)
# 18                                        Tomato (1kg)
# 19                                        Potato (1kg)
# 20                                         Onion (1kg)
# 21                                    Lettuce (1 head)
# 22                            Water (1.5 liter bottle)
# 23                          Bottle of Wine (Mid-Range)
# 24                    Domestic Beer (0.5 liter bottle)
# 25                   Imported Beer (0.33 liter bottle)
# 26                       Cigarettes 20 Pack (Marlboro)
# 27                    One-way Ticket (Local Transport)
# 28                        Monthly Pass (Regular Price)
# 29                          Taxi Start (Normal Tariff)
# 30                            Taxi 1km (Normal Tariff)
# 31                  Taxi 1hour Waiting (Normal Tariff)
# 32                                  Gasoline (1 liter)
# 33    Volkswagen Golf 1.4 90 KW Trendline (Or Equiva...
# 34    Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equ...
# 35    Basic (Electricity, Heating, Cooling, Water, G...
# 36    1 min. of Prepaid Mobile Tariff Local (No Disc...
# 37    Internet (60 Mbps or More, Unlimited Data, Cab...
# 38               Fitness Club, Monthly Fee for 1 Adult
# 39               Tennis Court Rent (1 Hour on Weekend)
# 40               Cinema, International Release, 1 Seat
# 41    Preschool (or Kindergarten), Full Day, Private...
# 42    International Primary School, Yearly for 1 Child
# 43              1 Pair of Jeans (Levis 501 Or Similar)
# 44    1 Summer Dress in a Chain Store (Zara, H&M, ...)
# 45            1 Pair of Nike Running Shoes (Mid-Range)
# 46                1 Pair of Men Leather Business Shoes
# 47                Apartment (1 bedroom) in City Centre
# 48             Apartment (1 bedroom) Outside of Centre
# 49               Apartment (3 bedrooms) in City Centre
# 50            Apartment (3 bedrooms) Outside of Centre
# 51    Price per Square Meter to Buy Apartment in Cit...
# 52    Price per Square Meter to Buy Apartment Outsid...
# 53              Average Monthly Net Salary (After Tax)
# 54    Mortgage Interest Rate in Percentages (%), Yea...
# Name: ITEMS, dtype: object

# %%
for country in COUNTRYLIST:
    df[country] = GetCountryPrices(country)
# Out:
# SELECTED COUNTRY: Afghanistan
#
# SELECTED COUNTRY: Aland+Islands
#
# SELECTED COUNTRY: Albania
#
# SELECTED COUNTRY: Alderney
#
# SELECTED COUNTRY: Algeria
#
# SELECTED COUNTRY: American+Samoa
#
# SELECTED COUNTRY: Andorra
#
# SELECTED COUNTRY: Angola
#
# SELECTED COUNTRY: Anguilla
#
# SELECTED COUNTRY: Antigua+And+Barbuda
#
# SELECTED COUNTRY: Argentina
#
# SELECTED COUNTRY: Armenia
#
# SELECTED COUNTRY: Aruba
#
# SELECTED COUNTRY: Australia
#
# SELECTED COUNTRY: Austria
#
# SELECTED COUNTRY: Azerbaijan
#
# SELECTED COUNTRY: Bahamas
#
# SELECTED COUNTRY: Bahrain
#
# SELECTED COUNTRY: Bangladesh
#
# SELECTED COUNTRY: Barbados
#
# SELECTED COUNTRY: Belarus
#
# SELECTED COUNTRY: Belgium
#
# SELECTED COUNTRY: Belize
#
# SELECTED COUNTRY: Benin
#
# SELECTED COUNTRY: Bermuda
#
# SELECTED COUNTRY: Bhutan
#
# SELECTED COUNTRY: Bolivia
#
# SELECTED COUNTRY: Bonaire
#
# SELECTED COUNTRY: Bosnia+And+Herzegovina
#
# SELECTED COUNTRY: Botswana
#
# SELECTED COUNTRY: Brazil
#
# SELECTED COUNTRY: British+Virgin+Islands
#
# SELECTED COUNTRY: Brunei
#
# SELECTED COUNTRY: Bulgaria
#
# SELECTED COUNTRY: Burkina+Faso
#
# SELECTED COUNTRY: Burundi
#
# SELECTED COUNTRY: Cambodia
#
# SELECTED COUNTRY: Cameroon
#
# SELECTED COUNTRY: Canada
#
# SELECTED COUNTRY: Cape+Verde
#
# SELECTED COUNTRY: Cayman+Islands
#
# SELECTED COUNTRY: Central+African+Republic
#
# SELECTED COUNTRY: Chad
#
# SELECTED COUNTRY: Chile
#
# SELECTED COUNTRY: China
#
# SELECTED COUNTRY: Colombia
#
# SELECTED COUNTRY: Comoros
#
# SELECTED COUNTRY: Congo
#
# SELECTED COUNTRY: Cook+Islands
#
# SELECTED COUNTRY: Costa+Rica
#
# SELECTED COUNTRY: Croatia
#
# SELECTED COUNTRY: Cuba
#
# SELECTED COUNTRY: Curacao
#
# SELECTED COUNTRY: Cyprus
#
# SELECTED COUNTRY: Czech+Republic
#
# SELECTED COUNTRY: Denmark
#
# SELECTED COUNTRY: Djibouti
#
# SELECTED COUNTRY: Dominica
#
# SELECTED COUNTRY: Dominican+Republic
#
# SELECTED COUNTRY: Ecuador
#
# SELECTED COUNTRY: Egypt
#
# SELECTED COUNTRY: El+Salvador
#
# SELECTED COUNTRY: Equatorial+Guinea
#
# SELECTED COUNTRY: Eritrea
#
# SELECTED COUNTRY: Estonia
#
# SELECTED COUNTRY: Ethiopia
#
# SELECTED COUNTRY: Falkland+Islands
#
# SELECTED COUNTRY: Faroe+Islands
#
# SELECTED COUNTRY: Fiji
#
# SELECTED COUNTRY: Finland
#
# SELECTED COUNTRY: France
#
# SELECTED COUNTRY: French+Guiana
#
# SELECTED COUNTRY: French+Polynesia
#
# SELECTED COUNTRY: French+Southern+Territories
#
# SELECTED COUNTRY: Gabon
#
# SELECTED COUNTRY: Gambia
#
# SELECTED COUNTRY: Georgia
#
# SELECTED COUNTRY: Germany
#
# SELECTED COUNTRY: Ghana
#
# SELECTED COUNTRY: Gibraltar
#
# SELECTED COUNTRY: Greece
#
# SELECTED COUNTRY: Greenland
#
# SELECTED COUNTRY: Grenada
#
# SELECTED COUNTRY: Guadeloupe
#
# SELECTED COUNTRY: Guam
#
# SELECTED COUNTRY: Guatemala
#
# SELECTED COUNTRY: Guernsey
#
# SELECTED COUNTRY: Guinea
#
# SELECTED COUNTRY: Guinea-Bissau
#
# SELECTED COUNTRY: Guyana
#
# SELECTED COUNTRY: Haiti
#
# SELECTED COUNTRY: Honduras
#
# SELECTED COUNTRY: Hong+Kong
#
# SELECTED COUNTRY: Hungary
#
# SELECTED COUNTRY: Iceland
#
# SELECTED COUNTRY: India
#
# SELECTED COUNTRY: Indonesia
#
# SELECTED COUNTRY: Iran
#
# SELECTED COUNTRY: Iraq
#
# SELECTED COUNTRY: Ireland
#
# SELECTED COUNTRY: Isle+Of+Man
#
# SELECTED COUNTRY: Israel
#
# SELECTED COUNTRY: Italy
#
# SELECTED COUNTRY: Ivory+Coast
#
# SELECTED COUNTRY: Jamaica
#
# SELECTED COUNTRY: Japan
#
# SELECTED COUNTRY: Jersey
#
# SELECTED COUNTRY: Jordan
#
# SELECTED COUNTRY: Kazakhstan
#
# SELECTED COUNTRY: Kenya
#
# SELECTED COUNTRY: Kosovo+%28Disputed+Territory%29
#
# SELECTED COUNTRY: Kuwait
#
# SELECTED COUNTRY: Kyrgyzstan
#
# SELECTED COUNTRY: Laos
#
# SELECTED COUNTRY: Latvia
#
# SELECTED COUNTRY: Lebanon
#
# SELECTED COUNTRY: Lesotho
#
# SELECTED COUNTRY: Liberia
#
# SELECTED COUNTRY: Libya
#
# SELECTED COUNTRY: Liechtenstein
#
# SELECTED COUNTRY: Lithuania
#
# SELECTED COUNTRY: Luxembourg
#
# SELECTED COUNTRY: Macao
#
# SELECTED COUNTRY: Madagascar
#
# SELECTED COUNTRY: Malawi
#
# SELECTED COUNTRY: Malaysia
#
# SELECTED COUNTRY: Maldives
#
# SELECTED COUNTRY: Mali
#
# SELECTED COUNTRY: Malta
#
# SELECTED COUNTRY: Marshall+Islands
#
# SELECTED COUNTRY: Martinique
#
# SELECTED COUNTRY: Mauritania
#
# SELECTED COUNTRY: Mauritius
#
# SELECTED COUNTRY: Mayotte
#
# SELECTED COUNTRY: Mexico
#
# SELECTED COUNTRY: Micronesia
#
# SELECTED COUNTRY: Moldova
#
# SELECTED COUNTRY: Monaco
#
# SELECTED COUNTRY: Mongolia
#
# SELECTED COUNTRY: Montenegro
#
# SELECTED COUNTRY: Montserrat
#
# SELECTED COUNTRY: Morocco
#
# SELECTED COUNTRY: Mozambique
#
# SELECTED COUNTRY: Myanmar
#
# SELECTED COUNTRY: Namibia
#
# SELECTED COUNTRY: Nepal
#
# SELECTED COUNTRY: Netherlands
#
# SELECTED COUNTRY: New+Caledonia
#
# SELECTED COUNTRY: New+Zealand
#
# SELECTED COUNTRY: Nicaragua
#
# SELECTED COUNTRY: Niger
#
# SELECTED COUNTRY: Nigeria
#
# SELECTED COUNTRY: North+Korea
#
# SELECTED COUNTRY: North+Macedonia
#
# SELECTED COUNTRY: Northern+Mariana+Islands
#
# SELECTED COUNTRY: Norway
#
# SELECTED COUNTRY: Oman
#
# SELECTED COUNTRY: Pakistan
#
# SELECTED COUNTRY: Palau
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-245f11c25bdf> in <module>
#       1 for country in COUNTRYLIST:
# ----> 2     df[country] = GetCountryPrices(country)
#
# <ipython-input-40-4a66a0fa2882> in GetCountryPrices(country)
#       8         prices = []
#       9         table = soup.find("table", class_="data_wide_table new_bar_table")
# ---> 10         row = table.find_all('tr')
#      11         for x in row:
#      12                 try:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
df.head

# %%
df.columns
# Out:
# Index(['ITEMS', 'Germany', 'United+States', 'Japan', 'China', 'France'], dtype='object')
